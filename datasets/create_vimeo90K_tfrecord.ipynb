# %% [markdown]
# ### file CSV. สำหรับ train เฉพาะ แหลังจากคัดเลือกภาพแล้ว
#
# '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_5FrameFilter/GlycerolRheology2023-train.csv'
#
#
#
# ### images Folder สำหรับ train/test เฉพาะ หลังจากคัดเลือกภาพแล้ว
#
# '/media/tohn/SSD/rheology_data/rheology2023/'

# %% [markdown]
# ### Train set

# %%
import pandas as pd

dfGlycerol = pd.read_csv('/home/kannika/code/rheology2023_Glycerol_train.csv')
print(f"Train set ==> {dfGlycerol.shape} ")
dfGlycerol.head()
# Out:
# Train set ==> (822, 2)
#    Unnamed: 0                                      Glycerol_Path
# 0           0  /media/SSD/rheology2023/Glycerol/GLY10/GLY10P1...
# 1           1  /media/SSD/rheology2023/Glycerol/GLY10/GLY10P1...
# 2           2  /media/SSD/rheology2023/Glycerol/GLY10/GLY10P1...
# 3           3  /media/SSD/rheology2023/Glycerol/GLY10/GLY10P1...
# 4           4  /media/SSD/rheology2023/Glycerol/GLY10/GLY10P1...

# %%
##****- Base root --> '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY__'

dfGlycerol['Glycerol_Path'] = dfGlycerol['Glycerol_Path'].str.replace('media/SSD/rheology2023','media/tohn/SSD/rheology_data/rheology2023')
z_ = dfGlycerol['Glycerol_Path'].tolist()
print(len(z_))
z_
# Out:
# 822
# ['/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184341',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_080610',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184804',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_205127',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_210329',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_194450',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_082117',
#  '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_080829',
# ...

# %%
dfGlycerol.to_csv('/home/kannika/code/rheology2023_Glycerol_train.csv')

# %% [markdown]
# ## Test set

# %%
df_test = pd.read_csv("/home/kannika/code/rheology2023_random40folder.csv")
print(f"Test set ==> {df_test.shape} ")
df_test.head()
# Out:
# Test set ==> (40, 2)
#    Unnamed: 0                                         FolderPath
# 0           0  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 1           1  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 2           2  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 3           3  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...
# 4           4  /media/SSD/rheology2023/DI/P0100_D0_30HZ_20XIN...

# %%
df_test['FolderPath'].tolist()
# Out:
# ['/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317',
#  '/media/SSD/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633',
#  '/media/SSD/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_072204',
#  '/media/SSD/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_074912',
# ...

# %%
##****- Base root --> '/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY__'
## ** -- older == '/media/SSD/rheology2023'

df_test['Glycerol_Path'] = df_test['FolderPath'].str.replace('media/SSD/rheology2023','media/tohn/SSD/rheology_data/rheology2023')
test_z_ = df_test['Glycerol_Path'].tolist()
print(len(test_z_))
test_z_
# Out:
# 40
# ['/media/tohn/SSD/rheology_data/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116',
#  '/media/tohn/SSD/rheology_data/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704',
#  '/media/tohn/SSD/rheology_data/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706',
#  '/media/tohn/SSD/rheology_data/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_214317',
#  '/media/tohn/SSD/rheology_data/rheology2023/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_215050',
#  '/media/tohn/SSD/rheology_data/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_121950',
#  '/media/tohn/SSD/rheology_data/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055220',
#  '/media/tohn/SSD/rheology_data/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_123202',
#  '/media/tohn/SSD/rheology_data/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221226_120633',
#  '/media/tohn/SSD/rheology_data/rheology2023/SalivaTU/SAL00_D0_30HZ_20XINF_UWELL_20221229_055529',
# ...

# %%
df_test.to_csv('/home/kannika/code/rheology2023_Glycerol_test.csv')

# %%
# df_test = pd.read_csv("/home/kannika/code/rheology2023_Glycerol_test.csv")
# print(f"Test set ==> {df_test.shape} ")
# df_test.head()

# %% [markdown]
# #### Root2Save == ''/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter"

# %%
import json 
import pandas as pd
import numpy as np
from pathlib import Path
import PIL
from PIL import Image
import cv2 
import tqdm
import os

# %% [markdown]
# ## Create Text file For Train Set

# %%
import glob

#tosave = '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter'
# original files = "/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311"
##Import data
dfGlycerol = pd.read_csv('/home/kannika/code/rheology2023_Glycerol_train.csv')
print(f"Train set ==> {dfGlycerol.shape[0]} ")
z_ = dfGlycerol['Glycerol_Path'].tolist() 
# Crete text files for prepare created sub directory
lstName2Save = list()
##**-- Create text file. 
for k in range(len(z_)) :
    pth = z_[k]
    txt_name = pth.split('/')[-1]
    print(f"text name: {txt_name}")
    f_name_toSave = pth.replace('rheology2023', "Frame_Inter_rheology2023/_3FrameFilter")
    ##**  pth.replace('rheology2023', "Frame_Inter_rheology2023/_3FrameFilter")
    f_name_toSave = f_name_toSave.split('/')[:-1]
    _f_name_toSave = '/'.join(f_name_toSave)
    txtname2save = _f_name_toSave+'/'+txt_name+'-train3line.txt'
    print(f"path2save files : {_f_name_toSave}")
    ## Create Directory
#     import imageio
#     os.makedirs(_f_name_toSave, exist_ok=True)

    ###**-- get images list --**
    files = glob.glob(f"{pth}/*")
    files.sort()
    ## Create dataframe for text.
    df = pd.DataFrame(files, columns =['Path'])
    df_ = df[:-2].reset_index(drop=True)
    #print(df_.shape)
    # df_
    df2 = pd.DataFrame(files, columns =['Path'])
    df2_ = df2[1:-1].reset_index(drop=True)
    #print(df2_.shape)
    #df2_ 
    df3 = pd.DataFrame(files, columns =['Path'])
    df3_ = df3[2:].reset_index(drop=True)
    #print(df3_.shape)
    #df3_ 
    df_['Path_txt'] = ''
    for i in range(len(df_)):
        name1 = df_['Path'][i]
        name2 = df2_['Path'][i]
        name3 = df3_['Path'][i]
        df_.loc[df_.index[i], 'Path_txt'] = str(name1)+' '+str(name2)+' '+str(name3)  
    print(df_.shape)
    list_path = df_['Path_txt'].tolist()
#     with open(txtname2save, 'w') as f:
#             for line in list_path:
#                  f.write(f"{line}\n")
    lstName2Save.append(txtname2save)
    print(f'On Process : Write text file name ==> [ {txtname2save} ] ')
## Save path text to dataframe.    
df_train_text = pd.DataFrame(lstName2Save, columns =['Path2text'])
df_train_text2csv = "/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/Glycerol2023_text-train.csv"
df_train_text.to_csv(df_train_text2csv)
print(f"Save Dataframe for text path as ===> [ {df_train_text2csv} ]")
# Out:
# Train set ==> 822
# text name: GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184341
# path2save files : /media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10
# (1999, 2)
# On Process : Write text file name ==> [ /media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184341-train3line.txt ]
# text name: GLY10P100_D0_30HZ_20XINF_UWELL_20221230_080610
# path2save files : /media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10
# (1999, 2)
# On Process : Write text file name ==> [ /media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_080610-train3line.txt ]
# text name: GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184804
# path2save files : /media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10
# (1999, 2)
# ...

# %%
list_path
# Out:
# ['/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129_0000000001.jpg /media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129_0000000002.jpg /media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_200129_0000000003.jpg',
# ...

# %%
lstName2Save
# Out:
# ['/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184341-train3line.txt',
#  '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221230_080610-train3line.txt',
#  '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_184804-train3line.txt',
#  '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_205127-train3line.txt',
#  '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_210329-train3line.txt',
#  '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/train/Glycerol/GLY10/GLY10P100_D0_30HZ_20XINF_UWELL_20221229_194450-train3line.txt',
# ...

# %% [markdown]
# ## Create Text file For Test Set

# %%
#tosave = '/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter'
# original files = "/media/tohn/SSD/rheology_data/rheology2023/Glycerol/GLY80/GLY80P100_D0_30HZ_20XINF_UWELL_20221228_122311"
##Import data
df_test = pd.read_csv("/home/kannika/code/rheology2023_random40folder.csv")
print(f"Test set ==> {df_test.shape[0]} ")
z_ = df_test['FolderPath'].tolist()
lstName2Save = list()
## Create Text file for Test ()
for k in range(len(z_)) :
    pth = z_[k]
    txt_name = pth.split('/')[-1]
    print(f"text name: {txt_name}")
    f_name_toSave =  pth.replace('rheology2023', "Frame_Inter_rheology2023/_3FrameFilter")
    f_name_toSave = f_name_toSave.split('/')[:-1]
    _f_name_toSave = '/'.join(f_name_toSave)
    txtname2save = _f_name_toSave+'/'+txt_name+'-test3line.txt'
    print(f"path2save files : {_f_name_toSave}")
    ## Create Directory
#     import imageio
#     os.makedirs(_f_name_toSave, exist_ok=True)

    ###**-- get images list --**
    files = glob.glob(f"{pth}/*")
    files.sort()
    files
    df = pd.DataFrame(files, columns =['Path'])
    df_ = df[:-2].reset_index(drop=True)
    #print(df_.shape)
    # df_
    df2 = pd.DataFrame(files, columns =['Path'])
    df2_ = df2[1:-1].reset_index(drop=True)
    #print(df2_.shape)
    #df2_ 
    df3 = pd.DataFrame(files, columns =['Path'])
    df3_ = df3[2:].reset_index(drop=True)
    #print(df3_.shape)
    #df3_ 
    df_['Path_txt'] = ''
    for i in range(len(df_)):
        name1 = df_['Path'][i]
        name2 = df2_['Path'][i]
        name3 = df3_['Path'][i]
        df_.loc[df_.index[i], 'Path_txt'] = str(name1)+' '+str(name2)+' '+str(name3)  
    print(df_.shape)
    list_path = df_['Path_txt'].tolist()
#     with open(txtname2save, 'w') as f:
#             for line in list_path:
#                  f.write(f"{line}\n")
    lstName2Save.append(txtname2save)
    print(f'On Process : Write text file name ==> [ {txtname2save} ] ')
## Save path text to dataframe.    
df_train_text = pd.DataFrame(lstName2Save, columns =['Path2text'])
df_train_text2csv = "/media/tohn/SSD/rheology_data/Frame_Inter_rheology2023/_3FrameFilter/Glycerol2023_text-test.csv"
df_train_text.to_csv(df_train_text2csv)
print(f"Save Dataframe for text path as ===> [ {df_train_text2csv} ] ")
# Out:
# Test set ==> 40
# text name: P0100_D0_30HZ_20XINF_UWELL_20221222_174116
# path2save files : /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI
# (0, 2)
# On Process : Write text file name ==> [ /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_174116-test3line.txt ]
# text name: P0100_D0_30HZ_20XINF_UWELL_20221222_182704
# path2save files : /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI
# (0, 2)
# On Process : Write text file name ==> [ /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI/P0100_D0_30HZ_20XINF_UWELL_20221222_182704-test3line.txt ]
# text name: P0100_D0_30HZ_20XINF_UWELL_20221223_122706
# path2save files : /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI
# (0, 2)
# On Process : Write text file name ==> [ /media/SSD/Frame_Inter_rheology2023/_3FrameFilter/DI/P0100_D0_30HZ_20XINF_UWELL_20221223_122706-test3line.txt ]
# text name: P0100_D0_30HZ_20XINF_UWELL_20221222_214317
# ...
